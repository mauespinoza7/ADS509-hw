# %% [markdown]
# # ADS 509 Module 1: APIs and Web Scraping
#
# This notebook has two parts. In the first part, you will scrape lyrics from AZLyrics.com. In the second part, you'll run code that verifies the completeness of your data pull.
#
# For this assignment you have chosen two musical artists who have at least 20 songs with lyrics on AZLyrics.com. We start with pulling some information and analyzing them.

# %% [markdown]
# ## General Assignment Instructions
#
# These instructions are included in every assignment, to remind you of the coding standards for the class. Feel free to delete this cell after reading it.
#
# One sign of mature code is conforming to a style guide. We recommend the [Google Python Style Guide](https://google.github.io/styleguide/pyguide.html). If you use a different style guide, please include a cell with a link.
#
# Your code should be relatively easy-to-read, sensibly commented, and clean. Writing code is a messy process, so please be sure to edit your final submission. Remove any cells that are not needed or parts of cells that contain unnecessary code. Remove inessential `import` statements and make sure that all such statements are moved into the designated cell.
#
# Make use of non-code cells for written commentary. These cells should be grammatical and clearly written. In some of these cells you will have questions to answer. The questions will be marked by a "Q:" and will have a corresponding "A:" spot for you. *Make sure to answer every question marked with a `Q:` for full credit.*

# %% [markdown]
# # Importing Libraries

# %% [markdown]
# ---
#
# # Lyrics Scrape
#
# This section asks you to pull data by scraping www.AZLyrics.com. In the notebooks where you do that work you are asked to store the data in specific ways.

# %%
artists = {'luis miguel':"https://www.azlyrics.com/l/luismiguel.html",
           'peso pluma':"https://www.azlyrics.com/p/pesopluma.html"}

# %% [markdown]
# ## A Note on Rate Limiting
#
# The lyrics site, www.azlyrics.com, does not have an explicit maximum on number of requests in any one time, but in our testing it appears that too many requests in too short a time will cause the site to stop returning lyrics pages. (Entertainingly, the page that gets returned seems to only have the song title to [a Tom Jones song](https://www.azlyrics.com/lyrics/tomjones/itsnotunusual.html).)
#
# Whenever you call `requests.get` to retrieve a page, put a `time.sleep(5 + 10*random.random())` on the next line. This will help you not to get blocked. If you _do_ get blocked, which you can identify if the returned pages are not correct, just request a lyrics page through your browser. You'll be asked to perform a CAPTCHA and then your requests should start working again.
#
# ## Part 1: Finding Links to Songs Lyrics
#
# That general artist page has a list of all songs for that artist with links to the individual song pages.
#
# Q: Take a look at the `robots.txt` page on www.azlyrics.com. (You can read more about these pages [here](https://developers.google.com/search/docs/advanced/robots/intro).) Is the scraping we are about to do allowed or disallowed by this page? How do you know?
#
# A: <!-- Delete this comment and put your answer here. -->

# %% [markdown]
# ## Part 2: Pulling Lyrics
#
# Now that we have the links to our lyrics pages, let's go scrape them! Here are the steps for this part.
#
# 1. Create an empty folder in our repo called "lyrics".
# 1. Iterate over the artists in `lyrics_pages`.
# 1. Create a subfolder in lyrics with the artist's name. For instance, if the artist was Cher you'd have `lyrics/cher/` in your repo.
# 1. Iterate over the pages.
# 1. Request the page and extract the lyrics from the returned HTML file using BeautifulSoup.
# 1. Use the function below, `generate_filename_from_url`, to create a filename based on the lyrics page, then write the lyrics to a text file with that name.

# %%
# Import necessary libraries
import os
import re
import time
import random
import shutil
import requests
from bs4 import BeautifulSoup
from collections import defaultdict, Counter
import sys # For potential error exit

# --- Configuration ---
# Define the artists to scrape - choose two artists with at least 20 songs each
# You can change these artists or add more following the format 'internal_name': 'azlyrics_artist_page_url'
ARTISTS = {
    'luis miguel': "https://www.azlyrics.com/l/luismiguel.html",
    'peso pluma': "https://www.azlyrics.com/p/pesopluma.html"
}

# Maximum number of songs to scrape per artist (to manage runtime)
MAX_SONGS_PER_ARTIST = 25

# Base directory to store lyrics
LYRICS_DIR = "lyrics"

# Politeness delay (seconds) between requests to avoid overloading the server
BASE_DELAY = 3
RANDOM_DELAY = 2


# --- Helper Functions ---

def generate_filename_from_link(link):
    """Generates a safe filename from an AZLyrics URL."""
    if not link:
        return None
    # Drop the schema and domain, remove .html
    name = link.replace("https://", "").replace("http://", "")
    name = name.replace("www.azlyrics.com/lyrics/", "")
    name = name.replace(".html", "")
    # Replace special characters with underscore
    name = re.sub(r'[^a-zA-Z0-9]+', '_', name)
    # Ensure it doesn't start/end with underscore
    name = name.strip('_')
    # Add .txt extension
    name = name + ".txt"
    return name

# Make the 'lyrics' folder 
if os.path.isdir("lyrics") : 
    shutil.rmtree("lyrics/")

os.mkdir("lyrics")

def words(text):
    """Extracts lowercase words from a text string."""
    return re.findall(r'\b\w+\b', text.lower()) # Use word boundaries for better tokenization

def polite_request(url):
    """Makes a request to a URL with a polite delay."""
    delay = BASE_DELAY + RANDOM_DELAY * random.random()
    print(f"    Waiting {delay:.2f}s before requesting {url}...")
    time.sleep(delay)
    try:
        response = requests.get(url, timeout=15) # Added timeout
        response.raise_for_status() # Raise an exception for bad status codes (4xx or 5xx)
        return response
    except requests.exceptions.RequestException as e:
        print(f"    Error requesting {url}: {e}")
        return None

# --- Main Script Logic ---

def scrape_artist_links(artists_dict):
    """Scrapes AZLyrics artist pages to get links to individual song lyrics."""
    lyrics_pages = defaultdict(list)
    print("Collecting song links for each artist...")
    for artist, artist_page_url in artists_dict.items():
        print(f"\nProcessing {artist}...")
        response = polite_request(artist_page_url)
        if response is None:
            print(f"Skipping {artist} due to request error.")
            continue

        soup = BeautifulSoup(response.text, 'html.parser')
        # Find the div containing the list of songs, often identified by id='listAlbum'
        song_list_div = soup.find('div', {'id': 'listAlbum'})

        if song_list_div:
            links = song_list_div.find_all('a', href=True)
            count = 0
            for link in links:
                href = link['href']
                # Ensure the link points to a lyrics page and format it correctly
                if href.startswith('../lyrics/') or href.startswith('/lyrics/'):
                    full_url = 'https://www.azlyrics.com' + href.replace('..', '')
                    if full_url not in lyrics_pages[artist]: # Avoid duplicates
                         lyrics_pages[artist].append(full_url)
                         count +=1

            print(f"Found {count} unique song links for {artist}.")
        else:
            print(f"Could not find song list div ('#listAlbum') for {artist}. Scraping might fail.")



    if not lyrics_pages:
        print("\nERROR: No artists with valid song links found. Exiting.")
        sys.exit(1) # Exit if no data can be scraped

    return lyrics_pages

def scrape_and_save_lyrics(lyrics_pages_dict, base_dir):
    """Scrapes lyrics for each song and saves them to files."""
    print(f"\nPreparing lyrics folder ('{base_dir}')...")
    if os.path.exists(base_dir):
        print(f"Removing existing directory: {base_dir}")
        shutil.rmtree(base_dir)
    os.makedirs(base_dir)
    print("Directory created.")

    print("\nScraping lyrics for selected songs...")
    start_time = time.time()
    total_pages_scraped = 0

    for artist, page_urls in lyrics_pages_dict.items():
        artist_dir = os.path.join(base_dir, artist)
        if not os.path.exists(artist_dir):
            os.makedirs(artist_dir)

        print(f"\nStarting scrape for {artist} (max {MAX_SONGS_PER_ARTIST} songs)...")
        songs_scraped_for_artist = 0

        # Shuffle the list to get a random sample if MAX_SONGS_PER_ARTIST is less than total
        random.shuffle(page_urls)

        for page_url in page_urls:
            if songs_scraped_for_artist >= MAX_SONGS_PER_ARTIST:
                print(f"Reached limit of {MAX_SONGS_PER_ARTIST} songs for {artist}.")
                break

            print(f"  Processing ({songs_scraped_for_artist + 1}/{MAX_SONGS_PER_ARTIST}): {page_url}")
            response = polite_request(page_url)
            if response is None:
                print(f"    Skipping song {page_url} due to request error.")
                continue

            try:
                soup = BeautifulSoup(response.text, 'html.parser')

                # Find the title - often in a <b> tag preceding the ringtone div
                title = "Unknown Title"
                title_tag = soup.find('h1') # Titles are often in <h1> now
                if title_tag:
                     title = title_tag.get_text(strip=True).replace(' Lyrics', '') # Clean up title
                else: # Fallback to older structure check
                    title_div = soup.find('div', {'class': 'ringtone'})
                    if title_div:
                         b_tag = title_div.find_previous_sibling('b')
                         if b_tag:
                             title = b_tag.text.strip().replace('"', '')


                # Find the lyrics - often the div immediately following the ringtone/usage div
                # Look for the div without class/id that contains lyrics
                lyrics = None
                lyrics_divs = soup.find_all('div', class_=None, id=None, attrs={'style': None})
                for div in lyrics_divs:
                    # Heuristic: The lyrics div usually contains multiple <br> tags
                    if div.find_all('br') and len(div.text.strip()) > 100: # Check length too
                        lyrics = div.text.strip()
                        break # Found likely lyrics div

                if lyrics:
                    filename = generate_filename_from_link(page_url)
                    if filename:
                        filepath = os.path.join(artist_dir, filename)
                        try:
                            with open(filepath, 'w', encoding='utf-8') as f:
                                f.write(f'"{title}"\n\n{lyrics}') # Include title in file
                            print(f"    -> Saved lyrics for '{title}' to {filename}")
                            total_pages_scraped += 1
                            songs_scraped_for_artist += 1
                        except IOError as e:
                            print(f"    Error writing file {filepath}: {e}")
                    else:
                        print(f"    Could not generate valid filename for {page_url}")
                else:
                    print(f"    Could not find lyrics structure on page {page_url}")

            except Exception as e:
                print(f"    Error processing page {page_url}: {e}")

    end_time = time.time()
    print(f"\nLyrics scraping finished.")
    print(f"Total run time: {round((end_time - start_time) / 60, 2)} minutes")
    print(f"Total song pages successfully scraped: {total_pages_scraped}")
    return total_pages_scraped > 0 # Return True if any lyrics were saved

def analyze_lyrics(base_dir):
    """Analyzes the scraped lyrics files to count word frequencies."""
    print("\nAnalyzing lyrics...")
    if not os.path.isdir(base_dir):
         print(f"Error: Lyrics directory '{base_dir}' not found. Cannot analyze.")
         return None

    artist_folders = [f for f in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, f))]

    if not artist_folders:
        print("No artist subdirectories found in lyrics folder.")
        return None

    artist_word_counts = {}

    for artist in artist_folders:
        artist_path = os.path.join(base_dir, artist)
        try:
            artist_files = [f for f in os.listdir(artist_path) if f.endswith('.txt')]
            print(f"\nAnalyzing {artist} ({len(artist_files)} files found)...")

            if not artist_files:
                print("  No text files found for this artist.")
                continue

            artist_words = []
            for f_name in artist_files:
                file_path = os.path.join(artist_path, f_name)
                try:
                    with open(file_path, 'r', encoding='utf-8') as infile:
                        # Skip the first line (title) if it exists
                        lines = infile.readlines()
                        if len(lines) > 1:
                             content = "".join(lines[1:]) # Join remaining lines
                             artist_words.extend(words(content))
                        elif lines: # Handle case with only title or empty file
                             artist_words.extend(words(lines[0]))

                except FileNotFoundError:
                    print(f"  Warning: File not found during analysis: {file_path}")
                except Exception as e:
                    print(f"  Error reading file {file_path}: {e}")

            if artist_words:
                word_counts = Counter(artist_words)
                artist_word_counts[artist] = word_counts
                unique_words = len(word_counts)
                total_words = len(artist_words)
                print(f"  -> Found roughly {total_words} words, {unique_words} unique.")

                # Print the most common words (length > 2)
                print(f"  Most common words for {artist} (length > 2):")
                print("  " + "-" * 30)
                print(f"  {'Word':<15} | {'Count':<10}")
                print("  " + "-" * 30)

                # Filter common words: length > 2, ignore very common English words if desired
                common_filtered = [(w, c) for w, c in word_counts.most_common(50) if len(w) > 2]
                # Optional: add stop word filtering here if needed
                for word, count in common_filtered[:10]: # Show top 10 after filtering
                    print(f"  {word:<15} | {count:<10}")
            else:
                 print("  No words extracted for this artist.")

        except Exception as e:
            print(f"An error occurred during analysis for {artist}: {e}")

    return artist_word_counts

def create_visualizations(artist_word_counts_dict):
    """Attempts to create and save bar charts comparing word frequencies."""
    if not artist_word_counts_dict:
         print("\nNo analysis data to create visualizations.")
         return

    print("\nAttempting to create visualizations...")
    try:
        import matplotlib.pyplot as plt

        num_artists = len(artist_word_counts_dict)
        if num_artists == 0:
             print("No artist data for plotting.")
             return

        # Create a figure with subplots for each artist
        # Adjust figsize based on number of artists
        fig, axes = plt.subplots(1, num_artists, figsize=(6 * num_artists, 7), squeeze=False)
        axes = axes.flatten() # Makes indexing easier

        for i, (artist, word_counts) in enumerate(artist_word_counts_dict.items()):
            # Get the 10 most common words with length > 2
            common_words_filtered = [(word, count) for word, count in word_counts.most_common(50) if len(word) > 2][:10]

            if not common_words_filtered:
                 axes[i].text(0.5, 0.5, 'No common words found', horizontalalignment='center', verticalalignment='center')
                 axes[i].set_title(f"{artist.replace('_', ' ').title()}")
                 axes[i].axis('off') # Hide axes if no data
                 continue

            words_list, counts = zip(*common_words_filtered)

            # Plot horizontally
            y_pos = range(len(words_list))
            axes[i].barh(y_pos, counts, align='center', color='skyblue')
            axes[i].set_yticks(y_pos)
            axes[i].set_yticklabels(words_list)
            axes[i].invert_yaxis()  # labels read top-to-bottom
            axes[i].set_xlabel("Frequency Count")
            axes[i].set_title(f"Top Words: {artist.replace('_', ' ').title()}")

        plt.tight_layout(pad=3.0) # Add padding
        plot_filename = "artist_word_comparison.png"
        plt.savefig(plot_filename)
        print(f"Visualization saved as '{plot_filename}'")
        # plt.show() # Optional: uncomment to display the plot interactively

    except ImportError:
        print("\nMatplotlib library not found. Skipping visualizations.")
        print("You can install it using: pip install matplotlib")
    except Exception as e:
        print(f"\nCould not create visualizations due to an error: {e}")

def compare_word_usage(artist_word_counts_dict):
    """Prints a table comparing the usage of common words across artists."""
    if not artist_word_counts_dict or len(artist_word_counts_dict) < 2:
        print("\nNeed word counts for at least two artists to compare usage.")
        return

    print("\nComparing word usage between artists:")
    print("=" * 50)

    # Find common words across all artists (top 100 from each, length > 2)
    all_top_words = set()
    for word_counts in artist_word_counts_dict.values():
        top_words = {word for word, count in word_counts.most_common(100) if len(word) > 2}
        all_top_words.update(top_words)

    # Select some interesting words to compare (e.g., top 20 alphabetically from the common set)
    comparison_words = sorted(list(all_top_words))[:20]

    if not comparison_words:
         print("No common words (length > 2) found across artists to compare.")
         return

    artist_list = list(artist_word_counts_dict.keys())

    # Print header
    header = f"{'Word':<15}"
    for artist in artist_list:
        header += f"| {artist:<15}"
    print(header)
    print("-" * len(header))

    # Print counts for each comparison word
    for word in comparison_words:
        row = f"{word:<15}"
        for artist in artist_list:
            count = artist_word_counts_dict[artist].get(word, 0) # Get count, default to 0 if word not found
            row += f"| {count:<15}"
        print(row)

# --- Execute the Workflow ---
if __name__ == "__main__":
    print("--- Starting Lyrics Scraping and Analysis ---")

    # 1. Get Song Links
    song_links = scrape_artist_links(ARTISTS)

    # 2. Scrape and Save Lyrics (only if links were found)
    lyrics_saved = False
    if song_links:
        lyrics_saved = scrape_and_save_lyrics(song_links, LYRICS_DIR)
    else:
        print("\nSkipping lyrics scraping as no valid song links were collected.")

    # 3. Analyze Lyrics (only if lyrics were saved)
    word_analysis_results = None
    if lyrics_saved:
        word_analysis_results = analyze_lyrics(LYRICS_DIR)
    else:
        print("\nSkipping analysis as no lyrics were successfully scraped.")

    # 4. Create Visualizations (only if analysis was done)
    if word_analysis_results:
        create_visualizations(word_analysis_results)

    # 5. Compare Word Usage (only if analysis was done)
    if word_analysis_results:
        compare_word_usage(word_analysis_results)

    print("\n--- Script Finished ---")
# Out:
# --- Starting Lyrics Scraping and Analysis ---
# Collecting song links for each artist...
#
# Processing luis miguel...
#     Waiting 4.92s before requesting https://www.azlyrics.com/l/luismiguel.html...
# Found 190 unique song links for luis miguel.
#
# Processing peso pluma...
#     Waiting 3.16s before requesting https://www.azlyrics.com/p/pesopluma.html...
# Found 89 unique song links for peso pluma.
#
# Preparing lyrics folder ('lyrics')...
# Removing existing directory: lyrics
# Directory created.
#
# Scraping lyrics for selected songs...
#
# Starting scrape for luis miguel (max 25 songs)...
#   Processing (1/25): https://www.azlyrics.com/lyrics/luismiguel/elviajero.html
#     Waiting 3.82s before requesting https://www.azlyrics.com/lyrics/luismiguel/elviajero.html...
#     -> Saved lyrics for 'Letra de "El Viajero"' to luismiguel_elviajero.txt
#   Processing (2/25): https://www.azlyrics.com/lyrics/luismiguel/ellaesas.html
#     Waiting 3.71s before requesting https://www.azlyrics.com/lyrics/luismiguel/ellaesas.html...
#     -> Saved lyrics for 'Letra de "Ella Es AsÃ­"' to luismiguel_ellaesas.txt
#   Processing (3/25): https://www.azlyrics.com/lyrics/luismiguel/talvezmemientes.html
#     Waiting 3.56s before requesting https://www.azlyrics.com/lyrics/luismiguel/talvezmemientes.html...
#     -> Saved lyrics for 'Letra de "Tal Vez Me Mientes"' to luismiguel_talvezmemientes.txt
#   Processing (4/25): https://www.azlyrics.com/lyrics/luismiguel/palomaquerida.html
#     Waiting 3.93s before requesting https://www.azlyrics.com/lyrics/luismiguel/palomaquerida.html...
#     -> Saved lyrics for 'Letra de "Paloma Querida"' to luismiguel_palomaquerida.txt
#   Processing (5/25): https://www.azlyrics.com/lyrics/luismiguel/lafiestadelmariachi.html
#     Waiting 3.44s before requesting https://www.azlyrics.com/lyrics/luismiguel/lafiestadelmariachi.html...
#     -> Saved lyrics for 'Letra de "La Fiesta Del Mariachi"' to luismiguel_lafiestadelmariachi.txt
#   Processing (6/25): https://www.azlyrics.com/lyrics/luismiguel/motivos.html
#     Waiting 3.29s before requesting https://www.azlyrics.com/lyrics/luismiguel/motivos.html...
#     -> Saved lyrics for 'Letra de "Motivos"' to luismiguel_motivos.txt
#   Processing (7/25): https://www.azlyrics.com/lyrics/luismiguel/frentealachimenea.html
#     Waiting 3.63s before requesting https://www.azlyrics.com/lyrics/luismiguel/frentealachimenea.html...
#     -> Saved lyrics for 'Letra de "Frente A La Chimenea"' to luismiguel_frentealachimenea.txt
#   Processing (8/25): https://www.azlyrics.com/lyrics/luismiguel/cruzdeolvido.html
#     Waiting 4.52s before requesting https://www.azlyrics.com/lyrics/luismiguel/cruzdeolvido.html...
#     -> Saved lyrics for 'Letra de "Cruz De Olvido"' to luismiguel_cruzdeolvido.txt
#   Processing (9/25): https://www.azlyrics.com/lyrics/luismiguel/estrenandoamor.html
#     Waiting 4.53s before requesting https://www.azlyrics.com/lyrics/luismiguel/estrenandoamor.html...
#     -> Saved lyrics for 'Letra de "Estrenando Amor"' to luismiguel_estrenandoamor.txt
#   Processing (10/25): https://www.azlyrics.com/lyrics/luismiguel/jrame.html
#     Waiting 3.04s before requesting https://www.azlyrics.com/lyrics/luismiguel/jrame.html...
#     -> Saved lyrics for 'Letra de "JÃºrame"' to luismiguel_jrame.txt
#   Processing (11/25): https://www.azlyrics.com/lyrics/luismiguel/nonmidevitrattarcosi.html
#     Waiting 4.25s before requesting https://www.azlyrics.com/lyrics/luismiguel/nonmidevitrattarcosi.html...
#     -> Saved lyrics for '"Non Mi Devi Trattar CosÃ¬" testo' to luismiguel_nonmidevitrattarcosi.txt
#   Processing (12/25): https://www.azlyrics.com/lyrics/luismiguel/nomeamenaces.html
#     Waiting 4.95s before requesting https://www.azlyrics.com/lyrics/luismiguel/nomeamenaces.html...
#     -> Saved lyrics for 'Letra de "No Me Amenaces"' to luismiguel_nomeamenaces.txt
#   Processing (13/25): https://www.azlyrics.com/lyrics/luismiguel/amoramoramor.html
#     Waiting 3.02s before requesting https://www.azlyrics.com/lyrics/luismiguel/amoramoramor.html...
#     -> Saved lyrics for 'Letra de "Amor, Amor, Amor"' to luismiguel_amoramoramor.txt
#   Processing (14/25): https://www.azlyrics.com/lyrics/luismiguel/qutristeza.html
#     Waiting 3.11s before requesting https://www.azlyrics.com/lyrics/luismiguel/qutristeza.html...
#     -> Saved lyrics for 'Letra de "QuÃ© Tristeza"' to luismiguel_qutristeza.txt
#   Processing (15/25): https://www.azlyrics.com/lyrics/luismiguel/msalldetodo.html
#     Waiting 3.00s before requesting https://www.azlyrics.com/lyrics/luismiguel/msalldetodo.html...
#     -> Saved lyrics for 'Letra de "MÃ¡s AllÃ¡ De Todo"' to luismiguel_msalldetodo.txt
#   Processing (16/25): https://www.azlyrics.com/lyrics/luismiguel/delirio.html
#     Waiting 4.21s before requesting https://www.azlyrics.com/lyrics/luismiguel/delirio.html...
#     -> Saved lyrics for 'Letra de "Delirio"' to luismiguel_delirio.txt
#   Processing (17/25): https://www.azlyrics.com/lyrics/luismiguel/yosquevolvers.html
#     Waiting 3.81s before requesting https://www.azlyrics.com/lyrics/luismiguel/yosquevolvers.html...
#     -> Saved lyrics for 'Letra de "Yo SÃ© Que VolverÃ¡s"' to luismiguel_yosquevolvers.txt
#   Processing (18/25): https://www.azlyrics.com/lyrics/luismiguel/queseasfeliz.html
#     Waiting 4.44s before requesting https://www.azlyrics.com/lyrics/luismiguel/queseasfeliz.html...
#     -> Saved lyrics for 'Letra de "Que Seas Feliz"' to luismiguel_queseasfeliz.txt
#   Processing (19/25): https://www.azlyrics.com/lyrics/luismiguel/vuelve.html
#     Waiting 3.63s before requesting https://www.azlyrics.com/lyrics/luismiguel/vuelve.html...
#     -> Saved lyrics for 'Letra de "Vuelve"' to luismiguel_vuelve.txt
#   Processing (20/25): https://www.azlyrics.com/lyrics/luismiguel/santaclausllegalaciudad.html
#     Waiting 4.34s before requesting https://www.azlyrics.com/lyrics/luismiguel/santaclausllegalaciudad.html...
#     -> Saved lyrics for 'Letra de "Santa Claus LlegÃ³ A La Ciudad"' to luismiguel_santaclausllegalaciudad.txt
#   Processing (21/25): https://www.azlyrics.com/lyrics/luismiguel/siento.html
#     Waiting 3.80s before requesting https://www.azlyrics.com/lyrics/luismiguel/siento.html...
#     -> Saved lyrics for 'Letra de "Siento"' to luismiguel_siento.txt
#   Processing (22/25): https://www.azlyrics.com/lyrics/luismiguel/porfavorseora.html
#     Waiting 4.99s before requesting https://www.azlyrics.com/lyrics/luismiguel/porfavorseora.html...
#     -> Saved lyrics for 'Letra de "Por Favor SeÃ±ora"' to luismiguel_porfavorseora.txt
#   Processing (23/25): https://www.azlyrics.com/lyrics/luismiguel/luzdeluna.html
#     Waiting 3.68s before requesting https://www.azlyrics.com/lyrics/luismiguel/luzdeluna.html...
#     -> Saved lyrics for 'Letra de "Luz De Luna"' to luismiguel_luzdeluna.txt
#   Processing (24/25): https://www.azlyrics.com/lyrics/luismiguel/contusbesos.html
#     Waiting 3.70s before requesting https://www.azlyrics.com/lyrics/luismiguel/contusbesos.html...
#     -> Saved lyrics for 'Letra de "Con Tus Besos"' to luismiguel_contusbesos.txt
#   Processing (25/25): https://www.azlyrics.com/lyrics/luismiguel/sinosdejan.html
#     Waiting 4.37s before requesting https://www.azlyrics.com/lyrics/luismiguel/sinosdejan.html...
#     -> Saved lyrics for 'Letra de "Si Nos Dejan"' to luismiguel_sinosdejan.txt
# Reached limit of 25 songs for luis miguel.
#
# Starting scrape for peso pluma (max 25 songs)...
#   Processing (1/25): https://www.azlyrics.com/lyrics/pesopluma/entreaguilas.html
#     Waiting 3.92s before requesting https://www.azlyrics.com/lyrics/pesopluma/entreaguilas.html...
#     -> Saved lyrics for 'Letra de "Entre Aguilas"' to pesopluma_entreaguilas.txt
#   Processing (2/25): https://www.azlyrics.com/lyrics/pesopluma/tuslindosversos.html
#     Waiting 4.75s before requesting https://www.azlyrics.com/lyrics/pesopluma/tuslindosversos.html...
#     -> Saved lyrics for 'Letra de "Tus Lindos Versos"' to pesopluma_tuslindosversos.txt
#   Processing (3/25): https://www.azlyrics.com/lyrics/pesopluma/elcapi.html
#     Waiting 4.80s before requesting https://www.azlyrics.com/lyrics/pesopluma/elcapi.html...
#     -> Saved lyrics for 'Letra de "El Capi"' to pesopluma_elcapi.txt
#   Processing (4/25): https://www.azlyrics.com/lyrics/pesopluma/vinotinto.html
#     Waiting 3.90s before requesting https://www.azlyrics.com/lyrics/pesopluma/vinotinto.html...
#     -> Saved lyrics for 'Letra de "VINO TINTO"' to pesopluma_vinotinto.txt
#   Processing (5/25): https://www.azlyrics.com/lyrics/pesopluma/spiral.html
#     Waiting 4.08s before requesting https://www.azlyrics.com/lyrics/pesopluma/spiral.html...
#     -> Saved lyrics for 'Letra de "Spiral"' to pesopluma_spiral.txt
#   Processing (6/25): https://www.azlyrics.com/lyrics/pesopluma/porlasnochesremix.html
#     Waiting 4.34s before requesting https://www.azlyrics.com/lyrics/pesopluma/porlasnochesremix.html...
#     -> Saved lyrics for 'Letra de "Por Las Noches (Remix)"' to pesopluma_porlasnochesremix.txt
#   Processing (7/25): https://www.azlyrics.com/lyrics/pesopluma/yoandoagusto.html
#     Waiting 3.73s before requesting https://www.azlyrics.com/lyrics/pesopluma/yoandoagusto.html...
#     -> Saved lyrics for 'Letra de "Yo Ando Agusto"' to pesopluma_yoandoagusto.txt
#   Processing (8/25): https://www.azlyrics.com/lyrics/pesopluma/sucasa.html
#     Waiting 4.49s before requesting https://www.azlyrics.com/lyrics/pesopluma/sucasa.html...
#     -> Saved lyrics for 'Letra de "SU CASA"' to pesopluma_sucasa.txt
#   Processing (9/25): https://www.azlyrics.com/lyrics/pesopluma/mami.html
#     Waiting 4.91s before requesting https://www.azlyrics.com/lyrics/pesopluma/mami.html...
#     -> Saved lyrics for 'Letra de "MAMI"' to pesopluma_mami.txt
#   Processing (10/25): https://www.azlyrics.com/lyrics/pesopluma/sembrando.html
#     Waiting 3.36s before requesting https://www.azlyrics.com/lyrics/pesopluma/sembrando.html...
#     -> Saved lyrics for 'Letra de "Sembrando"' to pesopluma_sembrando.txt
#   Processing (11/25): https://www.azlyrics.com/lyrics/pesopluma/rari.html
#     Waiting 4.51s before requesting https://www.azlyrics.com/lyrics/pesopluma/rari.html...
#     -> Saved lyrics for 'Letra de "RARI"' to pesopluma_rari.txt
#   Processing (12/25): https://www.azlyrics.com/lyrics/pesopluma/meactivo.html
#     Waiting 3.98s before requesting https://www.azlyrics.com/lyrics/pesopluma/meactivo.html...
#     -> Saved lyrics for 'Letra de "ME ACTIVO"' to pesopluma_meactivo.txt
#   Processing (13/25): https://www.azlyrics.com/lyrics/pesopluma/elchango.html
#     Waiting 3.26s before requesting https://www.azlyrics.com/lyrics/pesopluma/elchango.html...
#     -> Saved lyrics for 'Letra de "El Chango"' to pesopluma_elchango.txt
#   Processing (14/25): https://www.azlyrics.com/lyrics/pesopluma/lospixeliados.html
#     Waiting 4.42s before requesting https://www.azlyrics.com/lyrics/pesopluma/lospixeliados.html...
#     -> Saved lyrics for 'Letra de "Los Pixeliados"' to pesopluma_lospixeliados.txt
#   Processing (15/25): https://www.azlyrics.com/lyrics/pesopluma/productodela.html
#     Waiting 3.23s before requesting https://www.azlyrics.com/lyrics/pesopluma/productodela.html...
#     -> Saved lyrics for 'Letra de "Producto De La"' to pesopluma_productodela.txt
#   Processing (16/25): https://www.azlyrics.com/lyrics/pesopluma/peligro.html
#     Waiting 3.03s before requesting https://www.azlyrics.com/lyrics/pesopluma/peligro.html...
#     -> Saved lyrics for 'Letra de "Peligro"' to pesopluma_peligro.txt
#   Processing (17/25): https://www.azlyrics.com/lyrics/pesopluma/milhistorias.html
#     Waiting 4.52s before requesting https://www.azlyrics.com/lyrics/pesopluma/milhistorias.html...
#     -> Saved lyrics for 'Letra de "Mil Historias"' to pesopluma_milhistorias.txt
#   Processing (18/25): https://www.azlyrics.com/lyrics/pesopluma/bellakeo.html
#     Waiting 3.07s before requesting https://www.azlyrics.com/lyrics/pesopluma/bellakeo.html...
#     -> Saved lyrics for 'Letra de "BELLAKEO"' to pesopluma_bellakeo.txt
#   Processing (19/25): https://www.azlyrics.com/lyrics/pesopluma/mala.html
#     Waiting 4.99s before requesting https://www.azlyrics.com/lyrics/pesopluma/mala.html...
#     -> Saved lyrics for 'Letra de "MALA"' to pesopluma_mala.txt
#   Processing (20/25): https://www.azlyrics.com/lyrics/pesopluma/lamelena.html
#     Waiting 3.65s before requesting https://www.azlyrics.com/lyrics/pesopluma/lamelena.html...
#     -> Saved lyrics for 'Letra de "La Melena"' to pesopluma_lamelena.txt
#   Processing (21/25): https://www.azlyrics.com/lyrics/pesopluma/lapeople.html
#     Waiting 3.55s before requesting https://www.azlyrics.com/lyrics/pesopluma/lapeople.html...
#     -> Saved lyrics for 'Letra de "LA PEOPLE"' to pesopluma_lapeople.txt
#   Processing (22/25): https://www.azlyrics.com/lyrics/pesopluma/alleyoop.html
#     Waiting 3.79s before requesting https://www.azlyrics.com/lyrics/pesopluma/alleyoop.html...
#     -> Saved lyrics for 'Letra de "Alley Oop"' to pesopluma_alleyoop.txt
#   Processing (23/25): https://www.azlyrics.com/lyrics/pesopluma/yque.html
#     Waiting 3.74s before requesting https://www.azlyrics.com/lyrics/pesopluma/yque.html...
#     -> Saved lyrics for 'Letra de "Y QuÃ©?"' to pesopluma_yque.txt
#   Processing (24/25): https://www.azlyrics.com/lyrics/pesopluma/30tiros.html
#     Waiting 3.14s before requesting https://www.azlyrics.com/lyrics/pesopluma/30tiros.html...
#     -> Saved lyrics for 'Letra de "30 Tiros"' to pesopluma_30tiros.txt
#   Processing (25/25): https://www.azlyrics.com/lyrics/pesopluma/1414.html
#     Waiting 4.63s before requesting https://www.azlyrics.com/lyrics/pesopluma/1414.html...
#     -> Saved lyrics for 'Letra de "14 - 14"' to pesopluma_1414.txt
# Reached limit of 25 songs for peso pluma.
#
# Lyrics scraping finished.
# Total run time: 3.9 minutes
# Total song pages successfully scraped: 50
#
# Analyzing lyrics...
#
# Analyzing peso pluma (25 files found)...
#   -> Found roughly 5396 words, 1548 unique.
#   Most common words for peso pluma (length > 2):
#   ------------------------------
#   Word            | Count
#   ------------------------------
#   que             | 129
#   los             | 67
#   con             | 66
#   bien            | 47
#   las             | 42
#   bellakeo        | 41
#   para            | 37
#   por             | 36
#   aquã            | 33
#   pero            | 26
#
# Analyzing luis miguel (25 files found)...
#   -> Found roughly 3656 words, 907 unique.
#   Most common words for luis miguel (length > 2):
#   ------------------------------
#   Word            | Count
#   ------------------------------
#   que             | 116
#   amor            | 74
#   con             | 53
#   por             | 25
#   del             | 20
#   como            | 20
#   nos             | 19
#   tus             | 18
#   todo            | 17
#   vez             | 16
#
# Attempting to create visualizations...
# Visualization saved as 'artist_word_comparison.png'
#
# Comparing word usage between artists:
# ==================================================
# Word           | peso pluma     | luis miguel
# -------------------------------------------------
# ahã            | 8              | 5
# amar           | 0              | 9
# amenaces       | 0              | 8
# amigos         | 11             | 2
# amor           | 3              | 74
# anda           | 12             | 0
# ando           | 19             | 0
# aquã           | 33             | 1
# asi            | 0              | 10
# asã            | 16             | 6
# bella          | 2              | 9
# bellake        | 10             | 0
# bellakeo       | 41             | 0
# besos          | 1              | 15
# bien           | 47             | 4
# claus          | 0              | 8
# como           | 24             | 20
# compa          | 19             | 0
# con            | 66             | 53
# corazã³n       | 0              | 15
#
# --- Script Finished ---

# %%
print(f"Total run time was {round((time.time() - start)/3600,2)} hours.")

# %% [markdown]
# ## Checking Lyrics
#
# The output from your lyrics scrape should be stored in files located in this path from the directory:
# `/lyrics/[Artist Name]/[filename from URL]`. This code summarizes the information at a high level to help the instructor evaluate your work.

# %%
artist_folders = os.listdir("lyrics/")
artist_folders = [f for f in artist_folders if os.path.isdir("lyrics/" + f)]

for artist in artist_folders : 
    artist_files = os.listdir("lyrics/" + artist)
    artist_files = [f for f in artist_files if 'txt' in f or 'csv' in f or 'tsv' in f]

    print(f"For {artist} we have {len(artist_files)} files.")

    artist_words = []

    for f_name in artist_files : 
        with open("lyrics/" + artist + "/" + f_name) as infile : 
            artist_words.extend(words(infile.read()))

            
    print(f"For {artist} we have roughly {len(artist_words)} words, {len(set(artist_words))} are unique.")
